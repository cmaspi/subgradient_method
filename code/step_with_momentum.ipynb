# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import typing as ty
from matplotlib.animation import FuncAnimation

# %%
f1 = lambda x: -5*x-25
f2 = lambda x: -3*x-10
f3 = lambda x: -x+1
f4 = lambda x: 2*x+4
f5 = lambda x: 5*x-20


def f(functions: ty.Tuple[ty.Callable], x:np.ndarray) -> np.ndarray:
    max = functions[0](x)
    for function in functions[1:]:
        max = np.maximum(max, function(x))
    return max

def subgrad(functions: ty.Tuple[ty.Callable], x:float, dx: float = 1e-6) -> float:
    val = np.max([f(x+dx) for f in functions]) - np.max([f(x) for f in functions])
    return val/dx

# %%
x = np.linspace(-10,10,10000)
objective = f((f1,f2,f3,f4,f5),x)
plt.plot(x, objective)
plt.show()

# %%
x = np.linspace(-10,10,10000)
subgradients = np.array([subgrad((f1,f2,f3,f4,f5),i) for i in x])
plt.plot(x, subgradients)
plt.show()

# %% [markdown]
# # Constant step size
# Constant learning rate

# %%
def train(initial_guess, epochs: int):
    momentum = 0
    lr = (20/4)/np.sqrt(epochs)
    x = initial_guess
    vals = []
    minval = 1e9
    xcord = None
    vals.append(f((f1,f2,f3,f4,f5),x))
    if vals[-1]<minval:
        minval = vals[-1]
        xcord = x
    for epoch in range(epochs):
        x-=subgrad((f1,f2,f3,f4,f5),x) * lr + 0.9 * momentum
        momentum = subgrad((f1,f2,f3,f4,f5),x) * lr + 0.9 * momentum
        vals.append(f((f1,f2,f3,f4,f5),x))
        if vals[-1]<minval:
            minval = vals[-1]
            xcord = x
    return minval, xcord, vals    

n_epochs = 100
minval, xcord, vals = train(-5,n_epochs)
print(f'The minimum value obtained is {minval} which occurs at {xcord}')
# Out:
# The minimum value obtained is 2.0002513417359737 which occurs at -0.9998743291320131

# %%
# initializing a figure in 
# which the graph will be plotted
fig = plt.figure(dpi=500) 
   
# marking the x-axis and y-axis
axis = plt.axes(xlim =(0, n_epochs), 
                ylim =(1, 8)) 
  
# initializing a line variable
line, = axis.plot([], [], lw = 3) 
   
# data which the line will 
# contain (x, y)
def init(): 
    line.set_data([], [])
    return line,
   
def animate(i):
    global vals
    x = np.arange(1,i+1)
    y = vals[:i]
    line.set_data(x, y)   
    return line,
   
anim = FuncAnimation(fig, animate, init_func = init,
                     frames = n_epochs, interval = 20)
anim.save('../results/Constant_step_size.mp4', writer = 'ffmpeg', fps = 30)

# %% [markdown]
# # Constant step length
# Constant step length, that is
# $\displaystyle\alpha_k = \frac{\gamma}{\left|\left| g^{(k)} \right|\right|_2}$

# %%
def train(initial_guess, epochs: int):
    momentum = 0
    step_length = 1e-1
    x = initial_guess
    vals = []
    minval = 1e9
    xcord = None
    vals.append(f((f1,f2,f3,f4,f5),x))
    if vals[-1]<minval:
        minval = vals[-1]
        xcord = x
    for epoch in range(epochs):
        x-=np.sign(subgrad((f1,f2,f3,f4,f5),x)) * step_length + 0.9 * momentum
        momentum = np.sign(subgrad((f1,f2,f3,f4,f5),x)) * step_length + 0.9 * momentum
        vals.append(f((f1,f2,f3,f4,f5),x))
        if vals[-1]<minval:
            minval = vals[-1]
            xcord = x
    return minval, xcord, vals

epochs = 100
minval, xcord, vals = train(-5,epochs)
print(f'The minimum value obtained is {minval} which occurs at {xcord}')
# Out:
# The minimum value obtained is 2.0121407544743874 which occurs at -1.0121407544743877

# %%
# initializing a figure in 
# which the graph will be plotted
fig = plt.figure(dpi=500) 
   
# marking the x-axis and y-axis
axis = plt.axes(xlim =(0, n_epochs), 
                ylim =(1, 8)) 
  
# initializing a line variable
line, = axis.plot([], [], lw = 3) 
   
# data which the line will 
# contain (x, y)
def init(): 
    line.set_data([], [])
    return line,
   
def animate(i):
    global vals
    x = np.arange(1,i+1)
    y = vals[:i]
    line.set_data(x, y)   
    return line,
   
anim = FuncAnimation(fig, animate, init_func = init,
                     frames = n_epochs, interval = 20)
anim.save('../results/Constant_step_length.mp4', writer = 'ffmpeg', fps = 30)

# %% [markdown]
# # Square Summable but not summable
# $\left|\left|\alpha\right|\right|_2^2 = \sum \alpha_k^2 < \infty$
#
# $\sum \alpha_k \to \infty$

# %%
def train(initial_guess, epochs: int):
    momentum = 0
    lr = 1
    x = initial_guess
    vals = []
    minval = 1e9
    xcord = None
    vals.append(f((f1,f2,f3,f4,f5),x))
    if vals[-1]<minval:
        minval = vals[-1]
        xcord = x
    for epoch in range(epochs):
        x -= np.sign(subgrad((f1,f2,f3,f4,f5),x)) * lr / (epoch+1) + 0.9*  momentum
        momentum = np.sign(subgrad((f1,f2,f3,f4,f5),x)) * lr / (epoch+1) + 0.9* momentum
        vals.append(f((f1,f2,f3,f4,f5),x))
        if vals[-1]<minval:
            minval = vals[-1]
            xcord = x
    return minval, xcord, vals

epochs = 100
minval, xcord, vals = train(-5,epochs)
print(f'The minimum value obtained is {minval} which occurs at {xcord}')
# Out:
# The minimum value obtained is 2.0013343837340076 which occurs at -0.9993328081329962

# %%
# initializing a figure in 
# which the graph will be plotted
fig = plt.figure(dpi=500) 
   
# marking the x-axis and y-axis
axis = plt.axes(xlim =(0, n_epochs), 
                ylim =(1, 8)) 
  
# initializing a line variable
line, = axis.plot([], [], lw = 3) 
   
# data which the line will 
# contain (x, y)
def init(): 
    line.set_data([], [])
    return line,
   
def animate(i):
    global vals
    x = np.arange(1,i+1)
    y = vals[:i]
    line.set_data(x, y)   
    return line,
   
anim = FuncAnimation(fig, animate, init_func = init,
                     frames = n_epochs, interval = 20)
anim.save('../results/square_summable_but_not_summable.mp4', writer = 'ffmpeg', fps = 30)

# %% [markdown]
# # Non Summable Diminishing
# $\lim_{n\to \infty} \alpha_k = 0$
#
# $\sum \alpha_k \to \infty$

# %%
def train(initial_guess, epochs: int):
    momentum = 0 
    lr = 1
    x = initial_guess
    vals = []
    minval = 1e9
    xcord = None
    vals.append(f((f1,f2,f3,f4,f5),x))
    if vals[-1]<minval:
        minval = vals[-1]
        xcord = x
    for epoch in range(epochs):
        x -= np.sign(subgrad((f1,f2,f3,f4,f5),x)) * lr / (2 * np.sqrt((epoch+1))) + 0.9*momentum
        momentum = np.sign(subgrad((f1,f2,f3,f4,f5),x)) * lr / (2 * np.sqrt((epoch+1))) + 0.9*momentum
        vals.append(f((f1,f2,f3,f4,f5),x))
        if vals[-1]<minval:
            minval = vals[-1]
            xcord = x
    return minval, xcord, vals

epochs = 100
minval, xcord, vals = train(-5,epochs)
print(f'The minimum value obtained is {minval} which occurs at {xcord}')
# Out:
# The minimum value obtained is 2.0001687159559065 which occurs at -0.9999156420220467

# %%
# initializing a figure in 
# which the graph will be plotted
fig = plt.figure(dpi=500) 
   
# marking the x-axis and y-axis
axis = plt.axes(xlim =(0, n_epochs), 
                ylim =(1, 8)) 
  
# initializing a line variable
line, = axis.plot([], [], lw = 3) 
   
# data which the line will 
# contain (x, y)
def init(): 
    line.set_data([], [])
    return line,
   
def animate(i):
    global vals
    x = np.arange(1,i+1)
    y = vals[:i]
    line.set_data(x, y)   
    return line,
   
anim = FuncAnimation(fig, animate, init_func = init,
                     frames = n_epochs, interval = 20)
anim.save('../results/non_summable_diminishing.mp4', writer = 'ffmpeg', fps = 30)

# %% [markdown]
# # Non-Summable diminishing step lengths
# $\lim_{n\to \infty}\gamma_k = 0$
#
# $\sum \gamma_k \to \infty$

# %%
def train(initial_guess, epochs: int):
    momentum = 0
    step_length = 1
    x = initial_guess
    vals = []
    minval = 1e9
    xcord = None
    vals.append(f((f1,f2,f3,f4,f5),x))
    if vals[-1]<minval:
        minval = vals[-1]
        xcord = x
    for epoch in range(epochs):
        x-=np.sign(subgrad((f1,f2,f3,f4,f5),x)) * step_length / (epoch+1) + 0.9*momentum
        momentum = np.sign(subgrad((f1,f2,f3,f4,f5),x)) * step_length / (epoch+1) + 0.9*momentum
        vals.append(f((f1,f2,f3,f4,f5),x))
        if vals[-1]<minval:
            minval = vals[-1]
            xcord = x
    return minval, xcord, vals

epochs = 100
minval, xcord, vals = train(-5,epochs)
print(f'The minimum value obtained is {minval} which occurs at {xcord}')
# Out:
# The minimum value obtained is 2.0013343837340076 which occurs at -0.9993328081329962

# %%
# initializing a figure in 
# which the graph will be plotted
fig = plt.figure(dpi=500) 
   
# marking the x-axis and y-axis
axis = plt.axes(xlim =(0, n_epochs), 
                ylim =(1, 8)) 
  
# initializing a line variable
line, = axis.plot([], [], lw = 3) 
   
# data which the line will 
# contain (x, y)
def init(): 
    line.set_data([], [])
    return line,
   
def animate(i):
    global vals
    x = np.arange(1,i+1)
    y = vals[:i]
    line.set_data(x, y)   
    return line,
   
anim = FuncAnimation(fig, animate, init_func = init,
                     frames = n_epochs, interval = 20)
anim.save('../results/non_summable_diminishing_step_lengths.mp4', writer = 'ffmpeg', fps = 30)
